# %% [markdown]
# <a href="https://colab.research.google.com/github/KarolCastillo128/EPPL-rea-y-per-metro-de-un-circulo-a-mis-im-genes-/blob/main/El_profe_Karol_Castillo_0028.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Karol Castillo NL Fecha 25/mar/2026 ❤
# ---
# # Calcular Area y perimetro de un circulo
# ---
# ![Logo de Markdown](https://raw.githubusercontent.com/KarolCastillo128/EPPL-rea-y-per-metro-de-un-circulo-a-mis-im-genes-/refs/heads/main/circulo_area_perimetro.PNG)
# ---
# # formula para calcular Area
# $A=\pi*r^2$
# ---
# ## formula para calcular perimetro
# $P=2*\pi*r$
# ---
# ## Datos de entrada
# $r$ ?
# ---
# ## Diagrama de flujo en Lucidchart
# ![Logo de Markdown](https://raw.githubusercontent.com/KarolCastillo128/EPPL-rea-y-per-metro-de-un-circulo-a-mis-im-genes-/refs/heads/main/DF%20Area%20perimetro%20circulo.png)

# %%
# Calcular area y perimetro de un circulo
# Variables A,P, r
# formulas A = pi*r^2  y P = 2 * pi * r
# Capturar el valor de r
import math
print("Calcular area y perimetro de un circulo")
r = float(input("Ingrese el valor de r: "))
A =math.pi*r** 2
P = 2*math.pi*r
print("El area del circulo es: ", A)
print("El perimetro del circulo es: ", P)
print(" Karol Castillo NL = 9")
# Out:
# Calcular area y perimetro de un circulo
# Ingrese el valor de r: 5
# El area del circulo es:  78.53981633974483
# El perimetro del circulo es:  31.41592653589793
#  Karol Castillo NL = 9

# %% [markdown]
# # Relacion entre codigo y DF en Tldraw
# ![Logo de Markdown](https://raw.githubusercontent.com/KarolCastillo128/EPPL-rea-y-per-metro-de-un-circulo-a-mis-im-genes-/refs/heads/main/tldraw%20DF%20y%20codigo.png)
